# %%
# while문
a = 0 # 초기값
while (a<5): #조건식
    a+=1 #증감식
    print("실행문 : ",a)
# Out:
# 실행문 :  1
# 실행문 :  2
# 실행문 :  3
# 실행문 :  4
# 실행문 :  5

# %%
# break, continue문
a = 0 # 초기값
while (True): #조건식
    a+=1 #증감식
    if(a>5):
        break # 반복문 강제 종료
    if(a%2==0):
        continue # 다음 반복으로 건너뛰기
    print("실행문 : ",a)
# Out:
# 실행문 :  1
# 실행문 :  3
# 실행문 :  5

# %%
# for문
# for 변수 in 반복가능한자료형:
a = [5,4,3,2,1]
for i in a:
    print(i)
b = ["홍길동","이순신","손오공"]
for i in b:
    print(i)
# Out:
# 5
# 4
# 3
# 2
# 1
# 홍길동
# 이순신
# 손오공

# %%
# for문과 range함수
print(list(range(5))) # 0~4 까지
print(list(range(0 , 10+1 , 2))) # 0,2,4,6,8,10
# range(시작값, 끝값 + 1)
for i in range(5,10+1, 2):
    print(i)
# Out:
# [0, 1, 2, 3, 4]
# [0, 2, 4, 6, 8, 10]
# 5
# 7
# 9

# %%
a = 'a'
b = 13
print(a ,"x", b)
# Out:
# a x 13

# %%
# input("설명문") : 문자열로 데이터를 입력할 수 있도록 만드는 함수
str = input("입력해주세요>>")
print(str)
i = int(input("숫자를 입력해주세요>>"))
print(i+5)
# Out:
# a
# 15

# %%
a = "abcde"
# 문자열 길이  : len(문자열)
print(len(a))
b = [1,3,4,56,6,1,2,3]
print(len(b))
# Out:
# 5
# 8
